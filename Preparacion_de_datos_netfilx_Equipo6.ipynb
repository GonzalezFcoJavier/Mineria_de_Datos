# %% [markdown]
# <a href="https://colab.research.google.com/github/GonzalezFcoJavier/Mineria_de_Datos/blob/main/Preparacion_de_datos_netfilx_Equipo6.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Importamos librerias

# %%
import pandas as pd
import numpy as np
import json 
import csv

# %% [markdown]
# Lectura de datos

# %%
from google.colab import files
files.upload()

# %% [markdown]
# Visualizacion de los datos

# %%
df=pd.read_csv("netflixtitles.csv")
print(df) 
print(df.shape) 
print(df.head) 
print(df.tail)
print(df.columns)
# Out:
#      show_id  ...                                        description
# 0         s1  ...  In a future where the elite inhabit an island ...
# 1         s2  ...  After a devastating earthquake hits Mexico Cit...
# 2         s3  ...  When an army recruit is found dead, his fellow...
# 3         s4  ...  In a postapocalyptic world, rag-doll robots hi...
# 4         s5  ...  A brilliant group of students become card-coun...
# ...      ...  ...                                                ...
# 7782   s7783  ...  When Lebanon's Civil War deprives Zozo of his ...
# 7783   s7784  ...  A scrappy but poor boy worms his way into a ty...
# 7784   s7785  ...  In this documentary, South African rapper Nast...
# 7785   s7786  ...  Dessert wizard Adriano Zumbo looks for the nex...
# 7786   s7787  ...  This documentary delves into the mystique behi...
#
# [7787 rows x 12 columns]
# (7787, 12)
# <bound method NDFrame.head of      show_id  ...                                        description
# ...

# %% [markdown]
# En la primera columna marca la sucesion de los shows.
# Segunda columna, show_id simplemente marca la sucesion de los datos acompañads de una s.
# En las siguientes, menciona el titulo, tipo de show, año de estreno,  director, actores, raiting, duracion, por ultimo una breve descripcion de el show.

# %% [markdown]
# Cambiamos el nombre a las columnas

# %%
df=df.rename(columns = {'show_id':'Numero de show'})
df=df.rename(columns = {'description':'Descripcion del show'})
print(df)
# Out:
#      Numero de show  ...                               Descripcion del show
# 0                s1  ...  In a future where the elite inhabit an island ...
# 1                s2  ...  After a devastating earthquake hits Mexico Cit...
# 2                s3  ...  When an army recruit is found dead, his fellow...
# 3                s4  ...  In a postapocalyptic world, rag-doll robots hi...
# 4                s5  ...  A brilliant group of students become card-coun...
# ...             ...  ...                                                ...
# 7782          s7783  ...  When Lebanon's Civil War deprives Zozo of his ...
# 7783          s7784  ...  A scrappy but poor boy worms his way into a ty...
# 7784          s7785  ...  In this documentary, South African rapper Nast...
# 7785          s7786  ...  Dessert wizard Adriano Zumbo looks for the nex...
# 7786          s7787  ...  This documentary delves into the mystique behi...
#
# [7787 rows x 12 columns]

# %% [markdown]
# Para saber el tipo de dato de  la columna

# %%
df.dtypes

print( df[df['type']=='movie'])
# Out:
# Empty DataFrame
# Columns: [Numero de show, type, title, director, cast, country, date_added, release_year, rating, duration, listed_in, Descripcion del show]
# Index: []

# %% [markdown]
# Hacemos una agrupacion de los datos,  solo  mexico.

# %%
print(df.country.unique(),"\n")   #Para revisar los valores que se encuentran en la columna 
mexico=df[df['country']=='Mexico']  #Se aclara como se agruparán los datos, en este caso que cumpla que en la columna 'contry' diga 'Mexico'.
mexico.to_csv('Solo_Mexico.csv', index=False)

mexico
# Out:
# ['Brazil' 'Mexico' 'Singapore' 'United States' 'Turkey' 'Egypt' 'India'
#  'Poland, United States' 'Thailand' 'Nigeria' nan
#  'Norway, Iceland, United States' 'United Kingdom' 'Japan' 'South Korea'
#  'Italy' 'Canada' 'Indonesia' 'Romania' 'Spain' 'Iceland'
#  'South Africa, Nigeria' 'France' 'United States, South Africa'
#  'Portugal, Spain' 'Hong Kong, China, Singapore' 'United States, Germany'
#  'South Africa, China, United States' 'Argentina'
#  'United States, France, Serbia' 'Germany' 'Denmark, France, Poland'
#  'Poland' 'Kenya' 'New Zealand, United Kingdom' 'Pakistan' 'Australia'
#  'Australia, United States' 'Mexico, United States' 'United States, China'
#  'China, Hong Kong' 'Taiwan' 'United States, United Kingdom'
#  'France, South Korea, Japan' 'United States, Canada'
#  'United Kingdom, United States' 'Netherlands, Denmark, South Africa'
#  'Canada, United States' 'Denmark' 'Hong Kong'
#  'France, Netherlands, Singapore' 'China' 'Philippines'
# ...

# %% [markdown]
#    **¿Para que me puede servir estas agrupaciones para la práctica siguiente?**
#
#
#
# > Para poder identificar los datos de una manera mas sencilla y clara para su posterior análisis
#
#
#
# *   **Importancia del análisis previo de los datos antes de iniciar las modificaciones.**
#
# > Esto es de suma importancia debido a la necesidad de entender los datos con los que estamos trabajando, para poder así identificar la información que será relevante para nuestro análisis
